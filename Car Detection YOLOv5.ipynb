# %% [markdown]
# #  1 - Setup

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Car Detection YOLOv5/
# Out:
# /content/drive/MyDrive/Car Detection YOLOv5

# %%
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 2022-6-5 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 38.7/78.2 GB disk)

# %%
##!unzip -q ../train_data.zip -d ../

# %% [markdown]
# # 2 - Train

# %%
# !python train.py --img 640 --batch 2 --epochs 60 --data custom_data.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=custom_data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=60, batch_size=2, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# fatal: cannot change to '/content/drive/MyDrive/Car': No such file or directory
# YOLOv5 🚀 2022-6-5 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %% [markdown]
# # 3 - Test

# %%
# !python detect.py --weights runs/train/exp/weights/last.pt --img 640 --conf 0.25 --source data/images/car-1.jpg
# Out:
# detect: weights=['runs/train/exp5/weights/last.pt'], source=data/images/car-1.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# fatal: cannot change to '/content/drive/MyDrive/Car': No such file or directory
# YOLOv5 🚀 2022-6-5 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/drive/MyDrive/Car Detection YOLOv5/yolov5/data/images/car-1.jpg: 384x640 1 carro, Done. (0.017s)
# Speed: 0.5ms pre-process, 16.8ms inference, 1.2ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp8

# %%
display.Image(filename='runs/detect/exp8/car-1.jpg', width=600)

# %%
# !python detect.py --weights runs/train/exp5/weights/last.pt --img 640 --conf 0.25 --source data/video/traffic.mp4
# Out:
# detect: weights=['runs/train/exp5/weights/last.pt'], source=data/video/traffic.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# fatal: cannot change to '/content/drive/MyDrive/Car': No such file or directory
# YOLOv5 🚀 2022-6-5 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/2355) /content/drive/MyDrive/Car Detection YOLOv5/yolov5/data/video/traffic.mp4: 384x640 Done. (0.016s)
# video 1/1 (2/2355) /content/drive/MyDrive/Car Detection YOLOv5/yolov5/data/video/traffic.mp4: 384x640 Done. (0.010s)
# ...
